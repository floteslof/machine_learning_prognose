# %% [markdown]
# ## Manage Dataset

# %% [markdown]
# ### Import Packages

# %%
import pandas as pd

# %% [markdown]
# ### Import Dataframe from CSV File

# %%
# load csv file from github
url = 'https://raw.githubusercontent.com/floteslof/machine_learning_prognose/main/weather-stations-automated-sensors.csv'
df = pd.read_csv(url)
# Dataset is now stored in a Pandas Dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59144 entries, 0 to 59143
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Station Name                 59144 non-null  object
#  1   Measurement Timestamp        59141 non-null  object
#  2   Air Temperature              59066 non-null  float64
#  3   Wet Bulb Temperature         38843 non-null  float64
#  4   Humidity                     59141 non-null  float64
#  5   Rain Intensity               38843 non-null  float64
#  6   Interval Rain                59141 non-null  float64
#  7   Total Rain                   38843 non-null  float64
#  8   Precipitation Type           38843 non-null  float64
#  9   Wind Direction               59141 non-null  float64
#  10  Wind Speed                   59141 non-null  float64
#  11  Maximum Wind Speed           59141 non-null  float64
#  12  Barometric Pressure          58995 non-null  float64
#  13  Solar Radiation              59141 non-null  float64
#  14  Heading                      38843 non-null  float64
#  15  Battery Life                 59141 non-null  float64
#  16  Measurement Timestamp Label  59141 non-null  object
#  17  Measurement ID               59144 non-null  object
# dtypes: float64(14), object(4)
# memory usage: 8.1+ MB

# %% [markdown]
# ### Rename Columns

# %%
df = df.rename(columns={
    'Station Name': 'station_name',
    'Measurement Timestamp': 'date',
    'Air Temperature': 'air_temp',
    'Wet Bulb Temperature': 'wet_bulb_temp',
    'Humidity': 'humidity',
    'Rain Intensity': 'rain_intensity',
    'Interval Rain': 'interval_rain',
    'Total Rain': 'total_rain',
    'Precipitation Type': 'precipitation_type',
    'Wind Direction': 'wind_direction',
    'Wind Speed': 'wind_speed',
    'Maximum Wind Speed': 'max_wind_speed',
    'Barometric Pressure': 'barometric_pressure',
    'Solar Radiation': 'solar_radiation',
    'Heading': 'heading',
    'Battery Life': 'battery_life',
    'Measurement Timestamp Label': 'date_label',
    'Measurement ID': 'id'
})

df.head(3)
# Out:
#                  station_name                    date  air_temp  \
# 0  Oak Street Weather Station  05/22/2015 03:00:00 PM       NaN
# 1  Oak Street Weather Station  05/22/2015 05:00:00 PM       NaN
# 2  Oak Street Weather Station  05/22/2015 06:00:00 PM       NaN
#
#    wet_bulb_temp  humidity  rain_intensity  interval_rain  total_rain  \
# 0            7.0      55.0             0.0            0.0         1.4
# 1            6.3      56.0             0.0            0.0         1.4
# 2            6.5      54.0             0.0            0.0         1.4
#
#    precipitation_type  wind_direction  wind_speed  max_wind_speed  \
# 0                 0.0            63.0         1.9             2.8
# 1                 0.0           124.0         1.5             2.3
# 2                 0.0           156.0         1.9             3.4
#
#    barometric_pressure  solar_radiation  heading  battery_life  \
# 0                  NaN            780.0    322.0          12.0
# 1                  NaN            180.0    322.0          12.1
# 2                  NaN            127.0    322.0          12.1
#
#            date_label                                   id
# 0  05/22/2015 3:00 PM  OakStreetWeatherStation201505221500
# 1  05/22/2015 5:00 PM  OakStreetWeatherStation201505221700
# 2  05/22/2015 6:00 PM  OakStreetWeatherStation201505221800

# %% [markdown]
# ### Clean Up Table

# %% [markdown]
# #### Remove entries without date

# %%
df = df[df['date'].notna()]

# %% [markdown]
# #### Remove redundant columns

# %%
try:
  df = df.drop(columns=['date_label', 'id'])
except Exception:
  pass

df.head(3)
# Out:
#                  station_name                    date  air_temp  \
# 0  Oak Street Weather Station  05/22/2015 03:00:00 PM       NaN
# 1  Oak Street Weather Station  05/22/2015 05:00:00 PM       NaN
# 2  Oak Street Weather Station  05/22/2015 06:00:00 PM       NaN
#
#    wet_bulb_temp  humidity  rain_intensity  interval_rain  total_rain  \
# 0            7.0      55.0             0.0            0.0         1.4
# 1            6.3      56.0             0.0            0.0         1.4
# 2            6.5      54.0             0.0            0.0         1.4
#
#    precipitation_type  wind_direction  wind_speed  max_wind_speed  \
# 0                 0.0            63.0         1.9             2.8
# 1                 0.0           124.0         1.5             2.3
# 2                 0.0           156.0         1.9             3.4
#
#    barometric_pressure  solar_radiation  heading  battery_life
# 0                  NaN            780.0    322.0          12.0
# 1                  NaN            180.0    322.0          12.1
# 2                  NaN            127.0    322.0          12.1

# %% [markdown]
# ### Transform Timestamp

# %% [markdown]
# #### DateTime Information

# %% [markdown]
# Split up date for later processing

# %%
df['date'] = pd.to_datetime(df['date'], format='%m/%d/%Y %I:%M:%S %p')

df['year'] = df['date'].apply(lambda x : x.year)
df['month'] = df['date'].apply(lambda x : x.month)
df['day'] = df['date'].apply(lambda x : x.day)
df['hour'] = df['date'].apply(lambda x : x.hour)
df['minute'] = df['date'].apply(lambda x : x.minute)
df['weekday'] = df['date'].apply(lambda x : x.day_name())
df['weekofyear'] = df['date'].apply(lambda x : x.weekofyear)

df.head(3)
# Out:
#                  station_name                date  air_temp  wet_bulb_temp  \
# 0  Oak Street Weather Station 2015-05-22 15:00:00       NaN            7.0
# 1  Oak Street Weather Station 2015-05-22 17:00:00       NaN            6.3
# 2  Oak Street Weather Station 2015-05-22 18:00:00       NaN            6.5
#
#    humidity  rain_intensity  interval_rain  total_rain  precipitation_type  \
# 0      55.0             0.0            0.0         1.4                 0.0
# 1      56.0             0.0            0.0         1.4                 0.0
# 2      54.0             0.0            0.0         1.4                 0.0
#
#    wind_direction  ...  solar_radiation  heading  battery_life  year  month  \
# 0            63.0  ...            780.0    322.0          12.0  2015      5
# 1           124.0  ...            180.0    322.0          12.1  2015      5
# 2           156.0  ...            127.0    322.0          12.1  2015      5
#
#    day  hour  minute  weekday  weekofyear
# 0   22    15       0   Friday          21
# 1   22    17       0   Friday          21
# 2   22    18       0   Friday          21
#
# [3 rows x 23 columns]

# %% [markdown]
# #### Seasonal Information

# %% [markdown]
# Split up date into seasons

# %%
def month2seasons(x):
  if x in [12, 1, 2]:
      season = 'Winter'
  elif x in [3, 4, 5]:
      season = 'Spring'
  elif x in [6, 7, 8]:
      season = 'Summer'
  elif x in [9, 10, 11]:
      season = 'Autumn'

  return season

df['season'] = df['month'].apply(month2seasons)
df.head(3)
# Out:
#                  station_name                date  air_temp  wet_bulb_temp  \
# 0  Oak Street Weather Station 2015-05-22 15:00:00       NaN            7.0
# 1  Oak Street Weather Station 2015-05-22 17:00:00       NaN            6.3
# 2  Oak Street Weather Station 2015-05-22 18:00:00       NaN            6.5
#
#    humidity  rain_intensity  interval_rain  total_rain  precipitation_type  \
# 0      55.0             0.0            0.0         1.4                 0.0
# 1      56.0             0.0            0.0         1.4                 0.0
# 2      54.0             0.0            0.0         1.4                 0.0
#
#    wind_direction  ...  heading  battery_life  year  month  day  hour  minute  \
# 0            63.0  ...    322.0          12.0  2015      5   22    15       0
# 1           124.0  ...    322.0          12.1  2015      5   22    17       0
# 2           156.0  ...    322.0          12.1  2015      5   22    18       0
#
#    weekday  weekofyear  season
# 0   Friday          21  Spring
# 1   Friday          21  Spring
# 2   Friday          21  Spring
#
# [3 rows x 24 columns]

# %% [markdown]
# #### Daily Timing Information

# %%
def hours2timing(x):
    if x in [22,23,0,1,2,3]:
        timing = 'Night'
    elif x in range(4, 12):
        timing = 'Morning'
    elif x in range(12, 17):
        timing = 'Afternoon'
    elif x in range(17, 22):
        timing = 'Evening'
    else:
        timing = 'X'
    return timing

df['timing'] = df['hour'].apply(hours2timing)
df.head(3)
# Out:
#                  station_name                date  air_temp  wet_bulb_temp  \
# 0  Oak Street Weather Station 2015-05-22 15:00:00       NaN            7.0
# 1  Oak Street Weather Station 2015-05-22 17:00:00       NaN            6.3
# 2  Oak Street Weather Station 2015-05-22 18:00:00       NaN            6.5
#
#    humidity  rain_intensity  interval_rain  total_rain  precipitation_type  \
# 0      55.0             0.0            0.0         1.4                 0.0
# 1      56.0             0.0            0.0         1.4                 0.0
# 2      54.0             0.0            0.0         1.4                 0.0
#
#    wind_direction  ...  battery_life  year  month  day  hour  minute  weekday  \
# 0            63.0  ...          12.0  2015      5   22    15       0   Friday
# 1           124.0  ...          12.1  2015      5   22    17       0   Friday
# 2           156.0  ...          12.1  2015      5   22    18       0   Friday
#
#    weekofyear  season     timing
# 0          21  Spring  Afternoon
# 1          21  Spring    Evening
# 2          21  Spring    Evening
#
# [3 rows x 25 columns]

# %% [markdown]
# ### Export Dateset

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)
